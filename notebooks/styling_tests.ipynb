# %%
import pandas as pd
from chatbot.AN_Knowledge_Base import AN_KB_Manager

# %%
# import data
an_kb = AN_KB_Manager()
df_qna = pd.DataFrame(an_kb.qna_manager.get_unanswered_questions())

df_qna.head()
# Out:
# 2025-02-17 18:39:33,932 - knowledge_base_manager.core.qna_manager - INFO - Azure OpenAI LLM initialised successfully.
# /Users/bern/Documents/GitHub/fyp-chatbot/src/knowledge_base_manager/knowledge_base_manager/core/database_manager.py:17: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   self.client = pymongo.MongoClient(db_connection_str)
#                         _id  \
# 0  67b2f62a9ea817119e8e27fa
# 1  67b2f62d9ea817119e8e27fb
# 2  67b2f6359ea817119e8e27fd
# 3  67b2f6439ea817119e8e27ff
# 4  67b2f6469ea817119e8e2800
#
#                                             question answer      status  \
# 0       What is the date and time of my lab session?         Unanswered
# 1               What is the due date for exercise 5?         Unanswered
# 2         What is the usual average for the DS Quiz?         Unanswered
# ...

# %%
status_counts = df_qna['status'].value_counts()
print(status_counts)
# Out:
# status
# Unanswered    285
# Name: count, dtype: int64

# %%
# Define color formatting for the "Status" column
def status_color_formatter(status):
    if status == "Answered":
        return "background-color: #d4edda; color: #155724;" 
    elif status == "Unanswered":
        return "background-color: #f8d7da; color: #721c24;" 
    return ""  # default styling

# %%
df_qna.style.applymap(status_color_formatter, subset=pd.IndexSlice[:, ['status']])
# Out:
# /var/folders/18/8rj5byy12s5gsh3_tqf8h2kc0000gn/T/ipykernel_27596/3410348313.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df_qna.style.applymap(status_color_formatter, subset=pd.IndexSlice[:, ['status']])
# <style type="text/css">
# #T_b949a_row0_col3, #T_b949a_row1_col3, #T_b949a_row2_col3, #T_b949a_row3_col3, #T_b949a_row4_col3, #T_b949a_row5_col3, #T_b949a_row6_col3, #T_b949a_row7_col3, #T_b949a_row8_col3, #T_b949a_row9_col3, #T_b949a_row10_col3, #T_b949a_row11_col3, #T_b949a_row12_col3, #T_b949a_row13_col3 {
#   background-color: #f8d7da;
#   color: #721c24;
# }
# </style>
# <table id="T_b949a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b949a_level0_col0" class="col_heading level0 col0" >_id</th>
#       <th id="T_b949a_level0_col1" class="col_heading level0 col1" >question</th>
#       <th id="T_b949a_level0_col2" class="col_heading level0 col2" >answer</th>
# ...
