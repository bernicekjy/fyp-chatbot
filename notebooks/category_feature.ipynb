# %%
import os
from langchain_openai import AzureChatOpenAI
from langchain.callbacks import get_openai_callback

# %%
llm = AzureChatOpenAI(
            azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
            api_key=os.environ.get("AZURE_OPENAI_APIKEY"),
            deployment_name=os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME"),
            model_name=os.environ.get("AZURE_OPENAI_MODEL_NAME"),
            api_version=os.environ.get("AZURE_OPENAI_API_VERSION"),
            temperature=0,
        )

# %%
user_question = "What is the deadline for the mini project?"
categorise_prompt = f"""You are a helpful assistant for a course instructor. Your task is to categorize student questions into one of the following categories. You should return ONLY the category name in CAPITAL LETTERS. Do not explain your reasoning or provide additional text. Choose the most appropriate category from the list below:

CATEGORIES:
- ADMIN: Questions about deadlines, submission processes, group work policies, lab sites, or assignment logistics.
- TECHNICAL: Questions about programming errors, technical setup, or software issues.
- CONTENT: Questions about course material, lecture content, concepts, or explanations of topics.
- EVALUATION: Questions about grading criteria, marking schemes, or assessment feedback.
- RESOURCE: Questions requesting additional resources, study materials, or sample solutions.
- UNCATEGORISED: Questions that do not clearly fit into any of the above categories.
- IRRELEVANT: Questions that are unrelated to the course or inappropriate.

EXAMPLE 1
Question: "Where do I submit the mini project?"
Return: ADMIN

EXAMPLE 2
Question: "How do I resolve this error when installing the library?"
Return: TECHNICAL

EXAMPLE 3
Question: "Can you explain the concept of dynamic programming again?"
Return: CONTENT

EXAMPLE 4
Question: "How many marks is the final project worth?"
Return: EVALUATION

EXAMPLE 5
Question: "Do you have any sample solutions from last year’s exam?"
Return: RESOURCE

EXAMPLE 6
Question: "What’s the best pizza place near campus?"
Return: IRRELEVANT

EXAMPLE 7
Question: "I am confused about something but I’m not sure how to explain it."
Return: UNCATEGORISED

NOW CATEGORIZE THE FOLLOWING QUESTION:
Question: "{user_question}"
Return:

"""

# %%
# invoke LLM
with get_openai_callback() as cb:

    response = llm.invoke(categorise_prompt)

    # logger.info(
    #     f"=======[LLM COST] total cost: {cb.total_cost}; total tokens: {cb.total_tokens}"
    # )

    total_cost = cb.total_cost
    total_tokens = cb.total_tokens
        
response.content
# Out:
# 'ADMIN'

# %%
def categorise_question(user_question:str)->str:
    
    categorise_prompt = f"""You are a helpful assistant for a course instructor. Your task is to categorize student questions into one of the following categories. You should return ONLY the category name in CAPITAL LETTERS. Do not explain your reasoning or provide additional text. Choose the most appropriate category from the list below:

                            CATEGORIES:
                            - ADMIN: Questions about deadlines, submission processes, group work policies, lab sites, or assignment logistics.
                            - TECHNICAL: Questions about programming errors, technical setup, or software issues.
                            - CONTENT: Questions about course material, lecture content, concepts, or explanations of topics.
                            - EVALUATION: Questions about grading criteria, marking schemes, or assessment feedback.
                            - RESOURCE: Questions requesting additional resources, study materials, or sample solutions.
                            - UNCATEGORISED: Questions that do not clearly fit into any of the above categories.
                            - IRRELEVANT: Questions that are unrelated to the course or inappropriate.

                            EXAMPLE 1
                            Question: "Where do I submit the mini project?"
                            Return: ADMIN

                            EXAMPLE 2
                            Question: "How do I resolve this error when installing the library?"
                            Return: TECHNICAL

                            EXAMPLE 3
                            Question: "Can you explain the concept of dynamic programming again?"
                            Return: CONTENT

                            EXAMPLE 4
                            Question: "How many marks is the final project worth?"
                            Return: EVALUATION

                            EXAMPLE 5
                            Question: "Do you have any sample solutions from last year’s exam?"
                            Return: RESOURCE

                            EXAMPLE 6
                            Question: "What’s the best pizza place near campus?"
                            Return: IRRELEVANT

                            EXAMPLE 7
                            Question: "I am confused about something but I’m not sure how to explain it."
                            Return: UNCATEGORISED

                            NOW CATEGORIZE THE FOLLOWING QUESTION:
                            Question: "{user_question}"
                            Return:

                            """

    # invoke LLM
    with get_openai_callback() as cb:

        response = llm.invoke(categorise_prompt)

        # logger.info(
        #     f"=======[LLM COST] total cost: {cb.total_cost}; total tokens: {cb.total_tokens}"
        # )

        total_cost = cb.total_cost
        total_tokens = cb.total_tokens
            
    return response.content

# %%
categorise_question("What is the deadline for the mini project?")
# Out:
# 'ADMIN'

# %%
sample_questions = [
    # ADMIN
    "Where do I submit the final project?",
    "What is the deadline for the mini project?",
    "Do all team members need to submit, or just one?",
    "How do I register for the course next semester?",

    # ASSESSMENT
    "How is the final project graded?",
    "What is the weightage of the midterm exam?",
    "Can I resubmit my assignment for a better grade?",

    # CONTENT
    "Can you explain the difference between supervised and unsupervised learning?",
    "What is the time complexity of Dijkstra’s algorithm?",
    "How does backpropagation work in neural networks?",

    # TECHNICAL
    "I’m getting a ModuleNotFoundError when running my Python code—how can I fix this?",
    "How do I set up a virtual environment in Conda?",
    "Why is my code timing out on the server?",

    # LOGISTICS
    "What time does the lab session start?",
    "Is attendance mandatory for tutorials?",
    "Where is Lecture Hall B?",

    # GROUPWORK
    "How do we form teams for the mini project?",
    "Can we change group members after submitting the project?",
    "How do we handle conflicts within our team?",

    # UNCATEGORISED (Edge cases)
    "What’s a good laptop for programming?",
    "Can you recommend some good online courses?",
    "Is it okay to submit late if I have a medical emergency?",

    # IRRELEVANT
    "What’s the best coffee shop on campus?",
    "Where can I buy a new laptop?",
    "Can I bring my dog to class?"
]

# %%
for q in sample_questions:
    print(f"Question: {q}")
    print(f"Category: {categorise_question(q)}")
    print("\n")
# Out:
# Question: Where do I submit the final project?
# Category: ADMIN
#
#
# Question: What is the deadline for the mini project?
# Category: ADMIN
#
#
# Question: Do all team members need to submit, or just one?
# Category: ADMIN
#
#
# Question: How do I register for the course next semester?
# Category: ADMIN
#
#
# Question: How is the final project graded?
# Category: EVALUATION
#
#
# Question: What is the weightage of the midterm exam?
# Category: EVALUATION
#
#
# Question: Can I resubmit my assignment for a better grade?
# Category: ADMIN
#
#
# Question: Can you explain the difference between supervised and unsupervised learning?
# Category: CONTENT
#
#
# Question: What is the time complexity of Dijkstra’s algorithm?
# Category: CONTENT
#
#
# Question: How does backpropagation work in neural networks?
# Category: CONTENT
#
#
# Question: I’m getting a ModuleNotFoundError when running my Python code—how can I fix this?
# Category: TECHNICAL
#
#
# Question: How do I set up a virtual environment in Conda?
# Category: TECHNICAL
#
#
# Question: Why is my code timing out on the server?
# Category: TECHNICAL
#
#
# Question: What time does the lab session start?
# Category: ADMIN
#
#
# Question: Is attendance mandatory for tutorials?
# Category: ADMIN
#
#
# Question: Where is Lecture Hall B?
# Category: ADMIN
#
#
# Question: How do we form teams for the mini project?
# Category: ADMIN
#
#
# Question: Can we change group members after submitting the project?
# Category: ADMIN
#
#
# Question: How do we handle conflicts within our team?
# Category: ADMIN
#
#
# Question: What’s a good laptop for programming?
# Category: IRRELEVANT
#
#
# Question: Can you recommend some good online courses?
# Category: RESOURCE
#
#
# Question: Is it okay to submit late if I have a medical emergency?
# Category: ADMIN
#
#
# Question: What’s the best coffee shop on campus?
# Category: IRRELEVANT
#
#
# Question: Where can I buy a new laptop?
# Category: IRRELEVANT
#
#
# Question: Can I bring my dog to class?
# Category: IRRELEVANT
